# %% [markdown]
# # "LA_ID_12M_cont_0pad_PlusBasic" feature selection - TraceRatio

# %%
# !pip install ITMO_FS

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import sklearn.feature_selection as fs
import sklearn.metrics as mt
import sklearn.model_selection as ms
import sklearn.preprocessing as pp
import time as tm
import xgboost as xgb
from ITMO_FS.filters import univariate
from ITMO_FS.filters import multivariate
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline

# %%
RANDOM_STATE=4+8+15+16+23+42
NUM_FEATURES_TO_SELECT=10

# %%
# Cargar datos
X_raw = pd.read_csv("/content/drive/MyDrive/Documentos/7. educación/uniovi/master/tfm/data/LA_ID_12M_cont_0pad_PlusBasic_features.csv")
y_raw = pd.read_csv("/content/drive/MyDrive/Documentos/7. educación/uniovi/master/tfm/data/LA_ID_12M_cont_0pad_PlusBasic_labels.csv")
y = y_raw.iloc[:, 1:].values.ravel() # Las etiquetas están en la segunda columna

# %%
# Guardar los nombres de las características
original_feature_names = X_raw.columns.tolist()

# %%
# Preprocesamiento
pipe = Pipeline([
  ("feature_elimination", fs.VarianceThreshold()),
  ("scaler", pp.StandardScaler())
])
X_preprocessed = pipe.fit_transform(X_raw)
preprocessed_feature_names = pipe.get_feature_names_out(input_features=original_feature_names)
X = pd.DataFrame(X_preprocessed, columns=preprocessed_feature_names)

# %%
selector = multivariate.TraceRatioFisher(n_selected_features=NUM_FEATURES_TO_SELECT)

# Tomar el tiempo inicial
start_time = tm.time()

# Seleccionar las características más relevantes
X_selected = selector.fit_transform(X, y)
selected_features_names = X_selected.columns.tolist()

# Tomar el tiempo final
end_time = tm.time()

# Mostrar las características seleccionadas
print(f"*** Tiempo: {(end_time - start_time):.2f} segundos")
print(
  f"*** Características totales/seleccionadas: "
  f"{len(original_feature_names)}/{len(selected_features_names)}"
)
print(f"")
for i in range(len(selected_features_names)):
  print(f"{selected_features_names[i]}")
print("-" * 60)
# Out:
# *** Tiempo: 1.02 segundos
# *** Características totales/seleccionadas: 7669/10
#
# Age_years
# ant_fat-Mode intensity-T12--a45-d3-b10-w3-f5
# ant_fat-Mode intensity-T12--a360-d3-b20-w3-f3
# ant_fat-Skewness intensity-T12--a180-d3-b10-w1-f3
# ant_fat-Minimum intensity-T12--a135-d1-b10-w3-f1
# ant_fat-Mode intensity-T12--a360-d1-b10-w2-f5
# ant_fat-Maximum intensity-T12--a360-d3-b20-w1-f2
# ant_fat-Mode intensity-T12--a45-d3-b5-w3-f5
# ant_fat-Kurties intensity-T12--a180-d3-b10-w1-f3
# ant_fat-Minimum intensity-T12--a360-d3-b20-w1-f1
# ------------------------------------------------------------
